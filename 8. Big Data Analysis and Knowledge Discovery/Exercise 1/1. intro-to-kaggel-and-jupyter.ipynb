# %%
1+1
# Out:
# 2

# %% [markdown]
# This is Markdown cell

# %%
3/2
# Out:
# 1.5

# %%
# !pwd
# Out:
# /kaggle/working

# %%
a = 1
b = a + 1
c = b + a + 1
d = c + b + a + 1
a, b, c ,d
# Out:
# (1, 2, 4, 8)

# %%
import matplotlib.pyplot as plt

plt.plot([a,b,c,d])
plt.show()
